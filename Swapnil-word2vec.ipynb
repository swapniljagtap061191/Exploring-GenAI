#         4.33593750e-01, -4.02832031e-02,  1.00097656e-01,  3.84765625e-01,
#        -1.45507812e-01, -3.94531250e-01, -8.25195312e-02, -2.22656250e-01,
# ...

# %%
cat_vec=model['Swapnil']

# %%
cat_vec.shape
# Out:
# (300,)

# %%
model.most_similar("Swapnil")
# Out:
# [('Rohit', 0.7688314914703369),
#  ('Gaurav', 0.7665531635284424),
#  ('Tanmay', 0.7251332998275757),
#  ('Vinay', 0.7210646271705627),
#  ('Bhargav', 0.7176641225814819),
#  ('Sunil', 0.715273916721344),
#  ('Rajesh', 0.7151224613189697),
#  ('Santosh', 0.7140477299690247),
#  ('Nikhil', 0.7127928733825684),
#  ('Pankaj', 0.7112593054771423)]

# %%
model.most_similar("Komal")
# Out:
# [('Babita', 0.7091763615608215),
#  ('Neha', 0.7029078006744385),
#  ('Manisha', 0.6918762922286987),
#  ('Archana', 0.6915757060050964),
#  ('Savita', 0.6899687051773071),
#  ('Kanchan', 0.6834220290184021),
#  ('Pooja', 0.6821109056472778),
#  ('Kavita', 0.6804013252258301),
#  ('Geeta', 0.6785140037536621),
#  ('Rekha', 0.6780703663825989)]

# %%
model.most_similar("Jagtap")
# Out:
# [('Kadam', 0.7487777471542358),
#  ('Khaire', 0.7448299527168274),
#  ('Pednekar', 0.7307620644569397),
#  ('Gawde', 0.7304514050483704),
#  ('Kamble', 0.7235009074211121),
#  ('Shukla', 0.7144371867179871),
#  ('Suryavanshi', 0.7137554883956909),
#  ('Pathare', 0.7121760249137878),
#  ('Bhoir', 0.7086206674575806),
#  ('Jadhav', 0.7075198888778687)]

# %%
model.most_similar("Singh")
# Out:
# [('Sharma', 0.8103029727935791),
#  ('Prasad', 0.7462698221206665),
#  ('Verma', 0.7420960068702698),
#  ('Sinha', 0.7317132949829102),
#  ('Thakur', 0.7301909923553467),
#  ('Yadav', 0.7165684700012207),
#  ('Chauhan', 0.7160038948059082),
#  ('Mishra', 0.7127490639686584),
#  ('Vijay', 0.7111003994941711),
#  ('Randhawa', 0.7106507420539856)]

# %%
model.most_similar("Watson")
# Out:
# [('Hodge', 0.6596460938453674),
#  ('Fowler', 0.6557582020759583),
#  ('Smith', 0.6487021446228027),
#  ('Hurst', 0.6276392936706543),
#  ('Palmer', 0.6229941248893738),
#  ('Holmes', 0.616605281829834),
#  ('Bradshaw', 0.6113619804382324),
#  ('Spence', 0.6082261800765991),
#  ('Jones', 0.6057036519050598),
#  ('Evans', 0.6035352945327759)]

# %%
model.most_similar("Laptop")
# Out:
# [('laptop', 0.648013710975647),
#  ('Netbook', 0.6392863392829895),
#  ('Laptops', 0.6234564185142517),
#  ('laptops', 0.5806347131729126),
#  ('Gaming_Laptop', 0.562889575958252),
#  ('Laptop_Computer', 0.5615650415420532),
#  ('Child_OLPC_initiative', 0.5613320469856262),
#  ('Lenovo_ThinkPad_Edge', 0.5592522025108337),
#  ('Ultraportable', 0.5582396984100342),
#  ('Dell_Latitude_E####', 0.5526922941207886)]

# %%
model.most_similar("Jagtap")
